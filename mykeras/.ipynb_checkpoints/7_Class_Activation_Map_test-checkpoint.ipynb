# %% [markdown]
# ## Class Activation Map 실습
#
# 이번 실습에서는 ImageNet pretrained model에 대해서 class activation map을 구해봅니다

# %%
## library import
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image

print(tf.__version__)
print(keras.__version__)
# Out:
# /home/bit204/anaconda3/envs/python366/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/bit204/anaconda3/envs/python366/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/bit204/anaconda3/envs/python366/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input, decode_predictions

# %%
img_size = 299

# %%
## pretrained mobilenet load
mobilenet = InceptionResNetV2(weights='/home/bit204/Desktop/mykeras/cats_and_dogs_small_3.h5', include_top=False,
                     input_shape=(img_size,img_size,3))

# %%
mobilenet.trainable = False
mobilenet.summary()
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
## input image를 받아서, 마지막 feature map을 출력해주는 model 생성
target_fmap = mobilenet.get_layer(name='block8_10_conv').output
model = keras.models.Model(mobilenet.input, target_fmap)

# %%
## fully connected layer의 weight
weights = mobilenet.get_layer(name='conv_7b').get_weights()[0]
print(weights.shape)
# Out:
# (1, 1, 2080, 1536)

# %%
## weight reshape
weights = np.reshape(weights, (1024,-1))
print(weights.shape)
# Out:
# (1024, 3120)

# %%
## test image를 읽어와서 224, 224로 resize
from PIL import Image

cur_dir = os.getcwd()
img_path = os.path.join(cur_dir, 'datasets/train/old/', 'renew_73.jpg')
currimg = Image.open(img_path)
currimg = currimg.resize((img_size, img_size))
image = np.asarray(currimg)
image = np.reshape(image, (-1, img_size, img_size, 3))
print(image.shape)
# Out:
# (1, 299, 299, 3)

# %%
## 화면에 출력
plt.imshow(image[0])
plt.show()

# %%
## test image를 pretrained model에 넣고 feature map을 뽑음
fmap = model(preprocess_input(image))
fmap = np.reshape(np.array(fmap), (8,8,-1))
print(fmap.shape)

# %%
## test image에 대한 top-1 class 확인
prediction = mobilenet.predict(preprocess_input(image))

pred_class = np.argmax(prediction, -1)
pred_class
# Out:
# array([[[   0,    0,  352,  352, 1168, 1168,  178,  352],
#         [ 352,  352,  352,  177,  483, 1168,  322,  462],
#         [ 735, 1180,  725,  628,  483, 1508,  483, 1360],
#         [ 735, 1180,  369,  369,  223,  483,  483, 1360],
#         [ 369,  369,  369,  369, 1072,  903,  769,  352],
#         [ 735,  369,  369,  210,  210, 1072, 1224,  352],
#         [ 352,  513,  170,  337, 1124, 1124, 1124,  352],
#         [ 352,   78,  513, 1224, 1124, 1124, 1224,  352]]])

# %%
## top-1 외에 다른 class에 대한 label에 대해서도 CAM을 수행할 수 있도록 label list 생성
label_list = np.argsort(prediction, -1)
label_list = label_list[0, ::-1]
label_list[0]
# Out:
# array([[   0, 1027, 1026, ...,  237,  735,  352],
#        [   0, 1025, 1024, ...,  751,  722,   78],
#        [   0,  996,  994, ...,  312,  337,  513],
#        ...,
#        [   0,  955,  954, ..., 1070, 1461, 1124],
#        [   0,  972,  971, ...,  467,  845, 1224],
#        [   0, 1027, 1026, ...,  237,  735,  352]])

# %%
## top-5 확인
decode_predictions(prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-285-ff3365aa1e8a> in <module>
#       1 ## top-5 확인
# ----> 2 decode_predictions(prediction)
#
# ~/anaconda3/envs/python366/lib/python3.6/site-packages/tensorflow/python/keras/applications/__init__.py in wrapper(*args, **kwargs)
#      68       kwargs['models'] = models
#      69       kwargs['utils'] = utils
# ---> 70     return base_fun(*args, **kwargs)
#      71   return wrapper
#      72
#
# ~/anaconda3/envs/python366/lib/python3.6/site-packages/tensorflow/python/keras/applications/inception_resnet_v2.py in decode_predictions(*args, **kwargs)
#      36 @keras_modules_injection
#      37 def decode_predictions(*args, **kwargs):
# ---> 38   return inception_resnet_v2.decode_predictions(*args, **kwargs)
#      39
#      40
#
# ...

# %%
## top-5 class중 원하는 class에 대한 weight 가져오기
## 예) top-1 class: label_list[0], top-2 class: label_list[1], ...
#weights_cam = weights[:, pred_class[0]]
weights_cam = weights[:, label_list[2]]
print(len(weights_cam))
print(weights_cam[192])
# Out:
# 1024
# [[ 0.00201663 -0.00567933  0.01127046 ... -0.00250841 -0.01722324
#   -0.02215125]
#  [ 0.00201663 -0.02109361 -0.00253501 ... -0.00759671 -0.00262462
#   -0.01388846]
#  [-0.0001789   0.01593569 -0.00876578 ... -0.00262462 -0.02215125
#   -0.01388846]
#  ...
#  [ 0.00201663 -0.01643717 -0.00053844 ... -0.00250841 -0.00444841
#    0.0015626 ]
#  [ 0.00201663 -0.00720732  0.00987178 ...  0.03876438 -0.00044401
#   -0.01423452]
#  [ 0.00201663 -0.01281404 -0.01142856 ... -0.00250841 -0.02215125
#   -0.01722324]]

# %%
## CAM 만들기 (0으로 초기화한 후 weight x feature map을 누적해서 더함)
camsum = np.zeros((8,8))
for i in range(1024):
    camsum = camsum + weights_cam[i]*fmap[:,:,i]
camsum = camsum / 1024.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-287-79f6b5ed06db> in <module>
#       2 camsum = np.zeros((8,8))
#       3 for i in range(1024):
# ----> 4     camsum = camsum + weights_cam[i]*fmap[:,:,i]
#       5 camsum = camsum / 1024.
#
# ValueError: operands could not be broadcast together with shapes (8,1536) (8,8)

# %%
## 원본 image와 CAM 확인
fig1 = plt.figure(figsize=(10,6))
ax1 = fig1.add_subplot(1,2,1)
ax1.imshow(image[0])
ax1.set_title("Input Image")
ax2 = fig1.add_subplot(1,2,2)
ax2.imshow(camsum)
ax2.set_title("Class Activation Map")
plt.show()

# %%
## CAM을 0~1사이로 scaling
camsum /= camsum.max()
plt.matshow(camsum)
plt.show()
# Out:
# /home/bit204/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
#
# /home/bit204/.local/lib/python3.6/site-packages/matplotlib/image.py:397: UserWarning: Warning: converting a masked element to nan.
#   dv = (np.float64(self.norm.vmax) -
# /home/bit204/.local/lib/python3.6/site-packages/matplotlib/image.py:398: UserWarning: Warning: converting a masked element to nan.
#   np.float64(self.norm.vmin))
# /home/bit204/.local/lib/python3.6/site-packages/matplotlib/image.py:405: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /home/bit204/.local/lib/python3.6/site-packages/matplotlib/image.py:410: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# ...

# %% [markdown]
# ### CAM을 image로 저장

# %%
# !pip install opencv-python
import cv2

# %%
img = cv2.imread(img_path)
img = cv2.resize(img, (img_size, img_size))
camsum = cv2.resize(camsum, (img_size, img_size))
heatmap = np.uint8(255*camsum)

# %%
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)

# %%
## 원본 image와 CAM을 어느정도 비율로 섞을지 결정
superimposed_img = heatmap * 0.4 + img * 0.7

# %%
## file 저장할 경로
cam_path = os.path.join(cur_dir, 'catdog.jpg')

# %%
## file 저장
cv2.imwrite(cam_path, superimposed_img)
# Out:
# True

# %%
currimg = Image.open(cam_path)
image = np.asarray(currimg)
plt.figure(figsize=(5,5))
plt.imshow(image)
plt.show()
